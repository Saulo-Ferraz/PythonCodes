# %% [markdown]
# <a href="https://colab.research.google.com/github/Saulo-Ferraz/PythonCodes/blob/main/Atv_Prepara%C3%A7%C3%A3o_de_Dados_Saulo_Raphael.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <h align=centre><font size = 8>Preparação e transformação dos dados </font></h>

# %% [markdown]
# # Importing the necessary libraries
#
#
# 1: Import required libraries - Pandas, Numpy, and required classes for this task - ColumnTransformer, OneHotEncoder, LabelEncoder.

# %%
# Your code
import numpy as np
import pandas as pd
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, LabelEncoder

# %% [markdown]
# # Load the dataset --> titanic.csv
#
# 2: Start by loading the Titanic dataset into a pandas data frame. This can be done using the pd.read_csv function. The dataset's name is 'titanic.csv'.

# %%
# Your code
df = pd.read_csv('titanic.csv',delimiter = ';',header=(0))

print(df.shape)
df.head(25)
# Out:
# (183, 12)
#     PassengerId  Survived  Pclass  \
# 0             2         1       1
# 1             4         1       1
# 2             7         0       1
# 3            11         1       3
# 4            12         1       1
# 5            22         1       2
# 6            24         1       1
# 7            28         0       1
# 8            53         1       1
# 9            55         0       1
# 10           63         0       1
# 11           67         1       2
# 12           76         0       3
# 13           89         1       1
# 14           93         0       1
# 15           97         0       1
# 16           98         1       1
# 17          103         0       1
# 18          111         0       1
# 19          119         0       1
# 20          124         1       2
# 21          125         0       1
# 22          137         1       1
# 23          138         0       1
# 24          140         0       1
#
#                                                  Name     Sex   Age  SibSp  \
# 0   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 1        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 2                             McCarthy, Mr. Timothy J    male  54.0      0
# 3                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 4                            Bonnell, Miss. Elizabeth  female  58.0      0
# 5                               Beesley, Mr. Lawrence    male  34.0      0
# 6                        Sloper, Mr. William Thompson    male  28.0      0
# 7                      Fortune, Mr. Charles Alexander    male  19.0      3
# 8            Harper, Mrs. Henry Sleeper (Myna Haxtun)  female  49.0      1
# 9                      Ostby, Mr. Engelhart Cornelius    male  65.0      0
# 10                        Harris, Mr. Henry Birkhardt    male  45.0      1
# 11                       Nye, Mrs. (Elizabeth Ramell)  female  29.0      0
# 12                            Moen, Mr. Sigurd Hansen    male  25.0      0
# 13                         Fortune, Miss. Mabel Helen  female  23.0      3
# 14                        Chaffee, Mr. Herbert Fuller    male  46.0      1
# 15                          Goldschmidt, Mr. George B    male  71.0      0
# 16                    Greenfield, Mr. William Bertram    male  23.0      0
# 17                          White, Mr. Richard Frasar    male  21.0      0
# 18                     Porter, Mr. Walter Chamberlain    male  47.0      0
# 19                           Baxter, Mr. Quigg Edmond    male  24.0      0
# 20                                Webber, Miss. Susan  female  32.5      0
# 21                        White, Mr. Percival Wayland    male  54.0      0
# 22                       Newsom, Miss. Helen Monypeny  female  19.0      0
# 23                        Futrelle, Mr. Jacques Heath    male  37.0      1
# 24                                 Giglio, Mr. Victor    male  24.0      0
#
#     Parch       Ticket       Fare        Cabin Embarked
# 0       0     PC 17599    712.833          C85        C
# 1       0       113803       53.1         C123        S
# 2       0        17463    518.625          E46        S
# 3       1      PP 9549       16.7           G6        S
# 4       0       113783      26.55         C103        S
# 5       0       248698       13.0          D56        S
# 6       0       113788       35.5           A6        S
# 7       2        19950      263.0  C23 C25 C27        S
# 8       0     PC 17572    767.292          D33        C
# 9       1       113509    619.792          B30        C
# 10      0        36973     83.475          C83        S
# 11      0   C.A. 29395       10.5          F33        S
# 12      0       348123       7.65        F G73        S
# 13      2        19950      263.0  C23 C25 C27        S
# 14      0  W.E.P. 5734     61.175          E31        S
# 15      0     PC 17754    346.542           A5        C
# 16      1     PC 17759    633.583      D10 D12        C
# 17      1        35281    772.875          D26        S
# 18      0       110465       52.0         C110        S
# 19      1     PC 17558  2.475.208      B58 B60        C
# 20      0        27267       13.0         E101        S
# 21      1        35281    772.875          D26        S
# 22      2        11752    262.833          D47        S
# 23      0       113803       53.1         C123        S
# 24      0     PC 17593       79.2          B86        C

# %% [markdown]
# # Identify  target and dependent variables

# %%
# Your code
df.columns.values

print(df[['Survived', 'Name', 'Age']])
# Out:
#      Survived                                               Name   Age
# 0           1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0
# 1           1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0
# 2           0                            McCarthy, Mr. Timothy J  54.0
# 3           1                    Sandstrom, Miss. Marguerite Rut   4.0
# 4           1                           Bonnell, Miss. Elizabeth  58.0
# ..        ...                                                ...   ...
# 178         1   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  47.0
# 179         0                           Carlsson, Mr. Frans Olof  33.0
# 180         1      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  56.0
# 181         1                       Graham, Miss. Margaret Edith  19.0
# 182         1                              Behr, Mr. Karl Howell  26.0
#
# [183 rows x 3 columns]

# %% [markdown]
# # Identify the categorical data
# 3: Identify the categorical features in your dataset that need to be encoded. You can store these feature names in a list for easy access later.

# %%
# Your code
print(df.dtypes)

categorical_features = [col for col in df.columns if df[col].nunique() < 10]
print(categorical_features)
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare            object
# Cabin           object
# Embarked        object
# dtype: object
# ['Survived', 'Pclass', 'Sex', 'SibSp', 'Parch', 'Embarked']

# %% [markdown]
# # Implement an instance of the ColumnTransformer class
#
# 4: To apply OneHotEncoding to these categorical features, create an instance of the ColumnTransformer class. Make sure to pass the OneHotEncoder() as an argument along with the list of categorical features.

# %%
# Your code
categorical_features = ['Sex', 'Pclass', 'Embarked']
column_transformer = ColumnTransformer(
    transformers=[
        ('encoder', OneHotEncoder(), categorical_features)
    ],
    remainder='passthrough'  # mantém as colunas não transformadas
)

# %% [markdown]
# # Apply the fit_transform method on the instance of ColumnTransformer
#
# 5: Use the fit_transform method on the instance of ColumnTransformer to apply the OneHotEncoding.
#
# 6: The output of the fit_transform method should be converted into a NumPy array for further use

# %%
# Your code
df_encoded = column_transformer.fit_transform(df)

# %% [markdown]
# # Convert the output into a NumPy array

# %%
# Your code
df_encoded_array = column_transformer.fit_transform(df)

# Verificar o tipo e o shape do array resultante
print("Tipo do array:", type(df_encoded_array))
print("Shape do array:", df_encoded_array.shape)
# Out:
# Tipo do array: <class 'numpy.ndarray'>
# Shape do array: (183, 17)

# %% [markdown]
# # Use LabelEncoder to encode binary categorical data
# 7: The 'Survived' column in your dataset is the dependent variable. This is a binary categorical variable that should be encoded using LabelEncoder.

# %%
# Your code
label_encoder = LabelEncoder()

# Aplicar o LabelEncoder à coluna 'Survived'
df['Survived'] = label_encoder.fit_transform(df['Survived'])

# Verificar os valores únicos após a codificação
print("Valores únicos na coluna 'Survived' após a codificação:", df['Survived'].unique())
# Out:
# Valores únicos na coluna 'Survived' após a codificação: [1 0]

# %% [markdown]
# # Print the updated matrix of features and the dependent variable vector
#
# 8.  Print the updated matrix of features and the dependent variable vector

# %%
# Your code

# Imprimir a matriz de features atualizada
print("Matriz de Features:")
print(df_encoded_array)

# Imprimir o vetor da variável dependente
print("\nVetor da Variável Dependente:")
print(df['Survived'])
# Out:
# Matriz de Features:
# [[1.0 0.0 1.0 ... 'PC 17599' '712.833' 'C85']
#  [1.0 0.0 1.0 ... '113803' '53.1' 'C123']
#  [0.0 1.0 1.0 ... '17463' '518.625' 'E46']
#  ...
#  [1.0 0.0 1.0 ... '11767' '831.583' 'C50']
#  [1.0 0.0 1.0 ... '112053' '30.0' 'B42']
#  [0.0 1.0 1.0 ... '111369' '30.0' 'C148']]
#
# Vetor da Variável Dependente:
# 0      1
# 1      1
# 2      0
# 3      1
# 4      1
#       ..
# 178    1
# 179    0
# 180    1
# 181    1
# 182    1
# Name: Survived, Length: 183, dtype: int64
